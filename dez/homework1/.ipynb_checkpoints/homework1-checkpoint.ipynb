# %% [markdown]
# # Homework 1 for Data Engineering Zoomcamp

# %% [markdown]
# ## Prepare the data

# %%
import pandas as pd

# %%
data = pd.read_csv("green_tripdata_2019-10.csv.gz", low_memory=False)

# %%
data.describe()
# Out:
#             VendorID     RatecodeID   PULocationID   DOLocationID  \
# count  387007.000000  387007.000000  476386.000000  476386.000000
# mean        1.833509       1.102104     108.789746     129.697575
# std         0.372521       0.727587      71.420448      76.351002
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       1.000000      55.000000      65.000000
# 50%         2.000000       1.000000      82.000000     129.000000
# 75%         2.000000       1.000000     166.000000     193.000000
# max         2.000000      99.000000     265.000000     265.000000
#
#        passenger_count  trip_distance    fare_amount          extra  \
# count    387007.000000  476386.000000  476386.000000  476386.000000
# mean          1.308302       3.543614      15.782716       0.844550
# std           0.967869       4.168409      14.100716       1.135181
# min           0.000000      -6.930000    -200.000000      -4.500000
# ...

# %%
zone = pd.read_csv("taxi_zone_lookup.csv")
zone.describe()
# Out:
#        LocationID
# count  265.000000
# mean   133.000000
# std     76.643112
# min      1.000000
# 25%     67.000000
# 50%    133.000000
# 75%    199.000000
# max    265.000000

# %%
data.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-10-01 00:26:02   2019-10-01 00:39:58                  N
# 1       1.0  2019-10-01 00:18:11   2019-10-01 00:22:38                  N
# 2       1.0  2019-10-01 00:09:31   2019-10-01 00:24:47                  N
# 3       1.0  2019-10-01 00:37:40   2019-10-01 00:41:49                  N
# 4       2.0  2019-10-01 00:08:13   2019-10-01 00:17:56                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           112           196              1.0           5.88
# 1         1.0            43           263              1.0           0.80
# 2         1.0           255           228              2.0           7.50
# 3         1.0           181           181              1.0           0.90
# 4         1.0            97           188              1.0           2.52
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %% [markdown]
# ## Question 3. Trip Segmentation Count

# %%
data.loc[(data["trip_distance"] <= 1)].shape[0]
# Out:
# 104838

# %%
data.loc[(data["trip_distance"] > 1) & (data["trip_distance"] <= 3)].shape[0]
# Out:
# 199013

# %%
data.loc[(data["trip_distance"] > 3) & (data["trip_distance"] <= 7)].shape[0]
# Out:
# 109645

# %%
data.loc[(data["trip_distance"] > 7) & (data["trip_distance"] <= 10)].shape[0]
# Out:
# 27688

# %%
data.loc[(data["trip_distance"] > 10)].shape[0]
# Out:
# 35202

# %% [markdown]
# ## Question 4. Longest trip for each day
# I was lazy and just sorted everything by trip distance. The longest overall distance is the answer i beleave

# %%
data.sort_values(by="trip_distance").tail()
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 62935        2.0  2019-10-05 16:42:04   2019-10-05 18:51:30
# 293111       2.0  2019-10-24 10:59:58   2019-10-24 13:11:58
# 317407       2.0  2019-10-26 03:02:39   2019-10-26 07:44:59
# 141174       2.0  2019-10-11 20:34:21   2019-10-11 22:40:41
# 386795       2.0  2019-10-31 23:23:41   2019-11-01 13:01:07
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 62935                   N         5.0            33           265
# 293111                  N         1.0            14           265
# 317407                  N         5.0            36           265
# 141174                  N         4.0           126           265
# 386795                  N         5.0           129           265
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 62935               4.0          85.23        200.0   0.00      0.0
# ...

# %% [markdown]
# ## Question 5. Three biggest pickup zones

# %% [markdown]
# ## Question 6. Largest tip
# Need some more practice with joining dataframes, but i think the logic is right here
# 1. Locate the "East Harlem North" LocationID in the Zone table
# 2. Find data with this id = 74, and filter by date
# 3. Sort the data by tip amount
# 4. Find the LocationID 132, which has the largest tip

# %%
zone.loc[(zone["Zone"] == "East Harlem North")]
# Out:
#     LocationID    Borough               Zone service_zone
# 73          74  Manhattan  East Harlem North    Boro Zone

# %%
data.loc[(data["lpep_pickup_datetime"] >= "2019-10-1") & (data["lpep_pickup_datetime"] <= "2019-10-31") & (data["PULocationID"] == 74)].sort_values(by="tip_amount")
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 180382       2.0  2019-10-15 09:50:19   2019-10-15 09:54:04
# 262527       2.0  2019-10-21 16:10:15   2019-10-21 17:04:26
# 336575       2.0  2019-10-27 17:33:07   2019-10-27 17:45:35
# 302401       2.0  2019-10-24 22:43:21   2019-10-24 23:00:37
# 302403       1.0  2019-10-24 22:20:27   2019-10-24 22:32:53
# ...          ...                  ...                   ...
# 132044       1.0  2019-10-11 07:22:48   2019-10-11 07:56:22
# 251261       2.0  2019-10-20 15:14:27   2019-10-20 16:18:12
# 296026       2.0  2019-10-24 14:35:52   2019-10-24 14:36:32
# 340287       2.0  2019-10-28 06:05:56   2019-10-28 06:09:47
# 308891       2.0  2019-10-25 15:50:05   2019-10-25 16:50:07
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 180382                  N         1.0            74            75
# 262527                  N         1.0            74           205
# ...

# %%
zone.loc[zone["LocationID"] == 132]
# Out:
#      LocationID Borough         Zone service_zone
# 131         132  Queens  JFK Airport     Airports
